# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# # how to load data using seaborn

# %%
data=sns.load_dataset('iris')

# %%
data=pd.read_csv(r'C:\Users\Dell\Desktop\DATA analysis class\excel folder\olympics\iris.csv')
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data['Sepal.Length'], kde=True)
plt.show()

# %%
sns.histplot(data['Sepal.Width'], kde=True)
plt.show()

# %%
sns.scatterplot(data=data, x='Sepal.Length', y='Sepal.Width', hue='Species')
plt.show()

# %%
# hue asign colors to it base on the species for easy identification.
# sine these plot is without hue to identify the species will be very difficult
sns.scatterplot(data=data, x='Sepal.Length', y='Sepal.Width')
plt.show()

# %% [markdown]
# # Note: in seaborn the default name for data is data so in case your data name is not data
# # lets say your data name is irisInformation in this case then your representation should be
# # sns.lineplot(data=irisInformation, x='Sepal.Length', y='Sepal.Width', hue='Species') intead of sns.lineplot(data=data, x='Sepal.Length', y='Sepal.Width', hue='Species')

# %%
sns.lineplot(data=data, x='Sepal.Length', y='Sepal.Width', hue='Species')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df=pd.read_csv(r'C:\Users\Dell\Desktop\DATA analysis class\excel folder\olympics\iris.csv')
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.lineplot(data=df, x='Petal.Length', y='Petal.Width', hue='Species')
plt.savefig('daboh1.png')
plt.show()

# %%
sns.boxplot(data=df, x='Species', y='Petal.Length', hue='Species')
plt.show()

# %%
sns.boxplot(data=df, x='Petal.Width', y='Petal.Length', hue='Species')
plt.savefig('daboh.png')
plt.show()
